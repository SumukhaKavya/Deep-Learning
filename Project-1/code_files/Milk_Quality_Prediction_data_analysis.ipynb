# %%
# import required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'F:\Deep Learning Assignments\Project-1\milknew.csv')

# %% [markdown]
# ## load dataset

# %%
df.head()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# 4  6.6          37      0     0     0          0     255  medium

# %%
df.shape
# Out:
# (1059, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pH          1059 non-null   float64
#  1   Temprature  1059 non-null   int64
#  2   Taste       1059 non-null   int64
#  3   Odor        1059 non-null   int64
#  4   Fat         1059 non-null   int64
#  5   Turbidity   1059 non-null   int64
#  6   Colour      1059 non-null   int64
#  7   Grade       1059 non-null   object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 66.3+ KB

# %%
# renaming column
df=df.rename(columns={'Fat ':'Fat'})

# %% [markdown]
# ## Univariate Analysis

# %%
def discrete_univariate_analysis(discrete_data):
    for col_name in discrete_data:
        print("*"*10, col_name, "*"*10)
        print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
        print('Value Counts: \n', discrete_data[col_name].value_counts())
        print()

# %%
def numerical_univariate_analysis(numerical_data):
    for col_name in numerical_data:
        print("*"*10, col_name, "*"*10)
        print(numerical_data[col_name].agg(['count', 'min', 'max', 'mean', 'median', 'std', 'skew']))
        print()

# %%
discrete_df = df.select_dtypes(include=['object'])

numerical_df = df.select_dtypes(include=['float64', 'int64'])

# %%
discrete_univariate_analysis(discrete_df)
# Out:
# ********** Grade **********
# count                     1059
# nunique                      3
# unique     [high, low, medium]
# Name: Grade, dtype: object
# Value Counts:
#  low       429
# medium    374
# high      256
# Name: Grade, dtype: int64

# %%
numerical_univariate_analysis(numerical_df)
# Out:
# ********** pH **********
# count     1059.000000
# min          3.000000
# max          9.500000
# mean         6.630123
# median       6.700000
# std          1.399679
# skew        -0.683904
# Name: pH, dtype: float64
#
# ********** Temprature **********
# count     1059.000000
# min         34.000000
# max         90.000000
# mean        44.226629
# median      41.000000
# std         10.098364
# skew         2.216739
# Name: Temprature, dtype: float64
#
# ********** Taste **********
# count     1059.000000
# min          0.000000
# max          1.000000
# mean         0.546742
# median       1.000000
# std          0.498046
# skew        -0.188058
# Name: Taste, dtype: float64
#
# ********** Odor **********
# count     1059.000000
# min          0.000000
# max          1.000000
# mean         0.432483
# median       0.000000
# std          0.495655
# skew         0.272949
# Name: Odor, dtype: float64
#
# ********** Fat  **********
# count     1059.000000
# min          0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pH          1059 non-null   float64
#  1   Temprature  1059 non-null   int64
#  2   Taste       1059 non-null   int64
#  3   Odor        1059 non-null   int64
#  4   Fat         1059 non-null   int64
#  5   Turbidity   1059 non-null   int64
#  6   Colour      1059 non-null   int64
#  7   Grade       1059 non-null   object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 66.3+ KB

# %%
df['pH'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['pH'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Temprature'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Temprature'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Taste'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Odor'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Fat'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Turbidity'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Colour'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Grade'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.boxplot(x='Grade',y='pH',data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='pH'>

# %%
sns.boxplot(x='Grade',y='Temprature',data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='Temprature'>

# %%
df['Taste'] = df['Taste'].map({0: '0', 1: '1'})

sns.countplot(x='Grade', hue='Taste', data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='count'>

# %%
df['Odor'] = df['Odor'].map({0: '0', 1: '1'})

# Creating a grouped bar plot
sns.countplot(x='Grade', hue='Odor', data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='count'>

# %%
df['Fat'] = df['Fat'].map({0: '0', 1: '1'})

# Creating a grouped bar plot
sns.countplot(x='Grade', hue='Fat', data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='count'>

# %%
df['Turbidity'] = df['Turbidity'].map({0: '0', 1: '1'})

# Creating a grouped bar plot
sns.countplot(x='Grade', hue='Turbidity', data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='count'>

# %%
sns.boxplot(x='Grade',y='Colour',data=df)
# Out:
# <Axes: xlabel='Grade', ylabel='Colour'>

# %%
# Create Correlation heatmap
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12040\2481938319.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# <Axes: >
